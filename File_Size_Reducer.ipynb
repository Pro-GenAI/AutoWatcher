# %% [markdown]
# First please download the videos into original_videos folder. Then run the following code to reduce the file sizes.
#
# The video download URLs are available in the [README](README.md) file under "Video credits" section.
#
# If `ffmpeg` is not installed, please install using instructions from [ffmpeg.org/download.html](https://www.ffmpeg.org/download.html).

# %%
import os
import subprocess
import pandas as pd

original_videos_dir = 'original_videos'
if not os.path.exists(original_videos_dir):  # error if the folder does not exist
    raise FileNotFoundError(f'{original_videos_dir} does not exist')

# get list of files in original videos folder
files = os.listdir(original_videos_dir)
if not files or not len(files):  # error if no files found
	raise FileNotFoundError(f'No files found in {original_videos_dir}')

reduced_videos_dir = 'reduced_videos'
if os.path.exists(reduced_videos_dir):
    # delete all the files there
    files = os.listdir(reduced_videos_dir)
    for file in files:
        os.remove(os.path.join(reduced_videos_dir, file))
else:
    os.makedirs(reduced_videos_dir)

file_size_df = pd.DataFrame(columns=['File Name', 'Original Size (MB)', 'Reduced Size (KB)', 'Reduction Percentage'])

for file in files:
    original_file_path = os.path.join(original_videos_dir, file)
    reduced_file_path = os.path.join(reduced_videos_dir, file)
    original_file_size = os.path.getsize(original_file_path) / (1024 * 1024)

    # reduce resolution and frame rate using ffmpeg
    subprocess.run([
        'ffmpeg', '-i', original_file_path, '-vf', 'scale=640:360', '-r', '30', reduced_file_path
    ])

    reduced_file_size = os.path.getsize(reduced_file_path) / (1024 * 1024)
    reduction_percentage = ((original_file_size - reduced_file_size) / original_file_size) * 100

    # convert final file size to KB from MB
    reduced_file_size_kb = reduced_file_size * 1024

    # convert values to %.2f
    original_file_size = '%.2f' % original_file_size
    reduced_file_size_kb = '%.2f' % reduced_file_size_kb
    reduction_percentage = '%.2f' % reduction_percentage

    new_row = pd.DataFrame({
        'File Name': [file],
        'Original Size (MB)': [original_file_size],
        'Reduced Size (KB)': [reduced_file_size_kb],  # this is in KB, not MB
        'Reduction Percentage': [reduction_percentage]
    })
    file_size_df = pd.concat([file_size_df, new_row], ignore_index=True)

file_size_df
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm5 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'original_videos/mixkit-silent-thief-peeking-inside-a-house-31375-full-hd.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: isomavc1mp42
#     creation_time   : 2020-09-06T18:26:26.000000Z
#   Duration: 00:00:11.46, start: 0.000000, bitrate: 28334 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 28331 kb/s, 24 fps, 24 tbr, 24k tbn, 48 tbc (default)
#     Metadata:
#       creation_time   : 2020-09-06T18:26:26.000000Z
#       handler_name    : ETI ISO Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Elemental H.264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x613b8793f3c0] using SAR=1/1
# [libx264 @ 0x613b8793f3c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x613b8793f3c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x613b8793f3c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'reduced_videos/mixkit-silent-thief-peeking-inside-a-house-31375-full-hd.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: isomavc1mp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2020-09-06T18:26:26.000000Z
#       handler_name    : ETI ISO Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  344 fps=0.0 q=-1.0 Lsize=     461kB time=00:00:11.36 bitrate= 332.3kbits/s dup=69 drop=0 speed=13.5x
# video:456kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.075232%
# [libx264 @ 0x613b8793f3c0] frame I:2     Avg QP:20.52  size: 11249
# [libx264 @ 0x613b8793f3c0] frame P:103   Avg QP:22.05  size:  2973
# [libx264 @ 0x613b8793f3c0] frame B:239   Avg QP:24.33  size:   576
# [libx264 @ 0x613b8793f3c0] consecutive B-frames:  0.9% 18.6%  2.6% 77.9%
# [libx264 @ 0x613b8793f3c0] mb I  I16..4: 16.7% 63.9% 19.5%
# [libx264 @ 0x613b8793f3c0] mb P  I16..4:  1.4%  3.4%  0.5%  P16..4: 37.1%  9.6%  6.9%  0.0%  0.0%    skip:41.1%
# [libx264 @ 0x613b8793f3c0] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 30.4%  1.5%  0.2%  direct: 0.4%  skip:67.4%  L0:43.5% L1:52.1% BI: 4.4%
# [libx264 @ 0x613b8793f3c0] 8x8 transform intra:64.2% inter:81.1%
# [libx264 @ 0x613b8793f3c0] coded y,uvDC,uvAC intra: 45.6% 49.6% 13.7% inter: 6.9% 9.2% 0.1%
# [libx264 @ 0x613b8793f3c0] i16 v,h,dc,p: 63%  8%  8% 21%
# [libx264 @ 0x613b8793f3c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31%  7% 30%  4%  5%  8%  4%  5%  4%
# [libx264 @ 0x613b8793f3c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46%  8% 13%  4%  7% 11%  4%  5%  2%
# [libx264 @ 0x613b8793f3c0] i8c dc,h,v,p: 59% 10% 27%  5%
# [libx264 @ 0x613b8793f3c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x613b8793f3c0] ref P L0: 63.2% 18.2% 12.9%  5.7%
# [libx264 @ 0x613b8793f3c0] ref B L0: 87.6% 10.4%  1.9%
# [libx264 @ 0x613b8793f3c0] ref B L1: 98.0%  2.0%
# [libx264 @ 0x613b8793f3c0] kb/s:325.44
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm5 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'original_videos/3582-172488198.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.4.101
#   Duration: 00:00:08.80, start: 0.021000, bitrate: 2082 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 2079 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x63fb89c43240] using SAR=1/1
# [libx264 @ 0x63fb89c43240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x63fb89c43240] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x63fb89c43240] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'reduced_videos/3582-172488198.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  264 fps=0.0 q=-1.0 Lsize=     187kB time=00:00:08.70 bitrate= 176.1kbits/s dup=53 drop=0 speed=21.4x
# video:183kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.142354%
# [libx264 @ 0x63fb89c43240] frame I:2     Avg QP:20.63  size: 21798
# [libx264 @ 0x63fb89c43240] frame P:79    Avg QP:21.40  size:  1328
# [libx264 @ 0x63fb89c43240] frame B:183   Avg QP:24.19  size:   209
# [libx264 @ 0x63fb89c43240] consecutive B-frames:  1.5% 16.7%  4.5% 77.3%
# [libx264 @ 0x63fb89c43240] mb I  I16..4:  9.3% 56.4% 34.3%
# [libx264 @ 0x63fb89c43240] mb P  I16..4:  0.1%  0.8%  0.5%  P16..4: 16.2%  3.5%  3.2%  0.0%  0.0%    skip:75.8%
# [libx264 @ 0x63fb89c43240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  5.7%  0.7%  0.2%  direct: 0.2%  skip:93.1%  L0:33.4% L1:59.6% BI: 7.1%
# [libx264 @ 0x63fb89c43240] 8x8 transform intra:56.5% inter:69.5%
# [libx264 @ 0x63fb89c43240] coded y,uvDC,uvAC intra: 71.9% 67.6% 34.8% inter: 2.3% 2.8% 0.1%
# [libx264 @ 0x63fb89c43240] i16 v,h,dc,p: 12% 15%  4% 69%
# [libx264 @ 0x63fb89c43240] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 23% 14%  5%  6%  8%  6%  7%  6%
# [libx264 @ 0x63fb89c43240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 18% 10%  5% 10%  9% 11% 10%  5%
# [libx264 @ 0x63fb89c43240] i8c dc,h,v,p: 53% 23% 19%  5%
# [libx264 @ 0x63fb89c43240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x63fb89c43240] ref P L0: 74.5% 11.1% 10.6%  3.8%
# [libx264 @ 0x63fb89c43240] ref B L0: 88.9%  9.1%  2.0%
# [libx264 @ 0x63fb89c43240] ref B L1: 97.4%  2.6%
# [libx264 @ 0x63fb89c43240] kb/s:169.83
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm5 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x64c3265613c0] decoding for stream 1 failed
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'original_videos/vecteezy_bandit-with-gun-on-the-street_3287749.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     creation_time   : 2018-11-06T13:46:12.000000Z
#   Duration: 00:00:06.24, start: 0.000000, bitrate: 166149 kb/s
#   Stream #0:0(eng): Audio: aac (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 317 kb/s (default)
#     Metadata:
#       creation_time   : 2018-11-06T13:46:14.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 3840x2160, 165814 kb/s, 25 fps, 25 tbr, 25k tbn, 50 tbc (default)
#     Metadata:
#       creation_time   : 2018-11-06T13:46:14.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x64c32658f2c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x64c32658f2c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x64c32658f2c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'reduced_videos/vecteezy_bandit-with-gun-on-the-street_3287749.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2018-11-06T13:46:14.000000Z
#       handler_name    : ?Mainconcept Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2018-11-06T13:46:14.000000Z
#       handler_name    : #Mainconcept MP4 Sound Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame=  187 fps=104 q=-1.0 Lsize=     120kB time=00:00:06.20 bitrate= 157.8kbits/s dup=31 drop=0 speed=3.45x
# video:110kB audio:2kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.286683%
# [libx264 @ 0x64c32658f2c0] frame I:1     Avg QP:22.66  size:  5903
# [libx264 @ 0x64c32658f2c0] frame P:50    Avg QP:22.24  size:  1462
# [libx264 @ 0x64c32658f2c0] frame B:136   Avg QP:27.64  size:   240
# [libx264 @ 0x64c32658f2c0] consecutive B-frames:  1.1%  4.3%  4.8% 89.8%
# [libx264 @ 0x64c32658f2c0] mb I  I16..4: 13.8% 82.1%  4.1%
# [libx264 @ 0x64c32658f2c0] mb P  I16..4:  0.2%  1.6%  0.1%  P16..4: 38.2%  6.3%  2.5%  0.0%  0.0%    skip:51.1%
# [libx264 @ 0x64c32658f2c0] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 23.0%  0.4%  0.0%  direct: 0.1%  skip:76.3%  L0:47.3% L1:51.4% BI: 1.2%
# [libx264 @ 0x64c32658f2c0] 8x8 transform intra:84.0% inter:90.8%
# [libx264 @ 0x64c32658f2c0] coded y,uvDC,uvAC intra: 66.1% 64.0% 12.4% inter: 2.5% 3.9% 0.0%
# [libx264 @ 0x64c32658f2c0] i16 v,h,dc,p: 19% 10%  0% 71%
# [libx264 @ 0x64c32658f2c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 16%  6%  5%  7%  9% 10%  9%  6%
# [libx264 @ 0x64c32658f2c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 18%  7%  3%  8%  9%  8%  6%  3%
# [libx264 @ 0x64c32658f2c0] i8c dc,h,v,p: 50% 18% 25%  7%
# [libx264 @ 0x64c32658f2c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x64c32658f2c0] ref P L0: 54.2% 14.0% 24.2%  7.6%
# [libx264 @ 0x64c32658f2c0] ref B L0: 89.9%  8.6%  1.5%
# [libx264 @ 0x64c32658f2c0] ref B L1: 98.2%  1.8%
# [libx264 @ 0x64c32658f2c0] kb/s:143.28
# [aac @ 0x64c32657ed40] Qavg: 65536.000
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm5 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'original_videos/mixkit-two-thieves-recorded-on-a-security-camera-31372-full-hd.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: isomavc1mp42
#     creation_time   : 2020-09-06T18:17:02.000000Z
#   Duration: 00:00:21.46, start: 0.000000, bitrate: 24759 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 24756 kb/s, 24 fps, 24 tbr, 24k tbn, 48 tbc (default)
#     Metadata:
#       creation_time   : 2020-09-06T18:17:02.000000Z
#       handler_name    : ETI ISO Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Elemental H.264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5b51e4796c40] using SAR=1/1
# [libx264 @ 0x5b51e4796c40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5b51e4796c40] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x5b51e4796c40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'reduced_videos/mixkit-two-thieves-recorded-on-a-security-camera-31372-full-hd.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: isomavc1mp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2020-09-06T18:17:02.000000Z
#       handler_name    : ETI ISO Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  644 fps=463 q=-1.0 Lsize=     450kB time=00:00:21.36 bitrate= 172.5kbits/s dup=129 drop=0 speed=15.4x
# video:442kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.904507%
# [libx264 @ 0x5b51e4796c40] frame I:3     Avg QP:19.05  size: 12258
# [libx264 @ 0x5b51e4796c40] frame P:164   Avg QP:21.11  size:  2081
# [libx264 @ 0x5b51e4796c40] frame B:477   Avg QP:26.47  size:   154
# [libx264 @ 0x5b51e4796c40] consecutive B-frames:  0.5%  1.6%  2.3% 95.7%
# [libx264 @ 0x5b51e4796c40] mb I  I16..4: 15.2% 56.8% 28.0%
# [libx264 @ 0x5b51e4796c40] mb P  I16..4:  1.0%  4.1%  1.5%  P16..4: 20.5%  6.5%  3.5%  0.0%  0.0%    skip:63.0%
# [libx264 @ 0x5b51e4796c40] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 10.5%  0.3%  0.1%  direct: 0.1%  skip:89.0%  L0:53.8% L1:45.4% BI: 0.8%
# [libx264 @ 0x5b51e4796c40] 8x8 transform intra:60.4% inter:71.7%
# [libx264 @ 0x5b51e4796c40] coded y,uvDC,uvAC intra: 56.4% 0.0% 0.0% inter: 2.6% 0.0% 0.0%
# [libx264 @ 0x5b51e4796c40] i16 v,h,dc,p: 25% 18%  5% 53%
# [libx264 @ 0x5b51e4796c40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 13% 20%  7%  6%  7%  7%  8%  6%
# [libx264 @ 0x5b51e4796c40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 15% 20% 10%  7%  7%  7%  6%  5%
# [libx264 @ 0x5b51e4796c40] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x5b51e4796c40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5b51e4796c40] ref P L0: 68.1% 10.4% 14.7%  6.8%
# [libx264 @ 0x5b51e4796c40] ref B L0: 89.8%  8.2%  2.0%
# [libx264 @ 0x5b51e4796c40] ref B L1: 96.5%  3.5%
# [libx264 @ 0x5b51e4796c40] kb/s:168.24
# ffmpeg version 4.4.2-0ubuntu0.22.04.1+esm5 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.4.0-1ubuntu1~22.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1+esm5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'original_videos/mixkit-silent-thief-leaning-out-of-a-house-window-31379-full-hd.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: isomavc1mp42
#     creation_time   : 2020-09-06T18:34:21.000000Z
#   Duration: 00:00:12.58, start: 0.000000, bitrate: 24548 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 24545 kb/s, 24 fps, 24 tbr, 24k tbn, 48 tbc (default)
#     Metadata:
#       creation_time   : 2020-09-06T18:34:21.000000Z
#       handler_name    : ETI ISO Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Elemental H.264
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5f916d9f93c0] using SAR=1/1
# [libx264 @ 0x5f916d9f93c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5f916d9f93c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x5f916d9f93c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'reduced_videos/mixkit-silent-thief-leaning-out-of-a-house-window-31379-full-hd.mp4':
#   Metadata:
#     major_brand     : M4V
#     minor_version   : 1
#     compatible_brands: isomavc1mp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2020-09-06T18:34:21.000000Z
#       handler_name    : ETI ISO Video Media Handler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  377 fps=0.0 q=-1.0 Lsize=     550kB time=00:00:12.46 bitrate= 361.4kbits/s dup=75 drop=0 speed=13.7x
# video:545kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.967149%
# [libx264 @ 0x5f916d9f93c0] frame I:2     Avg QP:22.25  size: 16031
# [libx264 @ 0x5f916d9f93c0] frame P:113   Avg QP:23.35  size:  3425
# [libx264 @ 0x5f916d9f93c0] frame B:262   Avg QP:27.68  size:   527
# [libx264 @ 0x5f916d9f93c0] consecutive B-frames:  0.8% 18.0%  4.8% 76.4%
# [libx264 @ 0x5f916d9f93c0] mb I  I16..4: 12.1% 53.3% 34.6%
# [libx264 @ 0x5f916d9f93c0] mb P  I16..4:  0.6%  2.1%  0.9%  P16..4: 30.6% 14.9%  9.0%  0.0%  0.0%    skip:42.0%
# [libx264 @ 0x5f916d9f93c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 26.3%  2.5%  0.5%  direct: 0.5%  skip:70.1%  L0:40.2% L1:55.0% BI: 4.8%
# [libx264 @ 0x5f916d9f93c0] 8x8 transform intra:56.6% inter:70.0%
# [libx264 @ 0x5f916d9f93c0] coded y,uvDC,uvAC intra: 63.5% 64.4% 35.1% inter: 6.8% 6.0% 0.3%
# [libx264 @ 0x5f916d9f93c0] i16 v,h,dc,p: 62% 12%  7% 19%
# [libx264 @ 0x5f916d9f93c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37%  7% 22%  5%  5%  7%  4%  8%  4%
# [libx264 @ 0x5f916d9f93c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43%  8% 13%  7%  5%  7%  4%  8%  4%
# [libx264 @ 0x5f916d9f93c0] i8c dc,h,v,p: 48% 10% 38%  4%
# [libx264 @ 0x5f916d9f93c0] Weighted P-Frames: Y:0.9% UV:0.0%
# [libx264 @ 0x5f916d9f93c0] ref P L0: 68.0% 17.6% 10.1%  4.2%  0.0%
# [libx264 @ 0x5f916d9f93c0] ref B L0: 93.2%  5.7%  1.2%
# [libx264 @ 0x5f916d9f93c0] ref B L1: 98.7%  1.3%
# [libx264 @ 0x5f916d9f93c0] kb/s:354.67
#                                            File Name Original Size (MB)  \
# 0  mixkit-silent-thief-peeking-inside-a-house-313...              38.70
# 1                                 3582-172488198.mp4               2.18
# 2  vecteezy_bandit-with-gun-on-the-street_3287749...             123.59
# 3  mixkit-two-thieves-recorded-on-a-security-came...              63.33
# 4  mixkit-silent-thief-leaning-out-of-a-house-win...              36.82
#
#   Reduced Size (KB) Reduction Percentage
# 0            461.11                98.84
# 1            187.03                91.64
# 2            119.57                99.91
# 3            449.95                99.31
# 4            550.02                98.54
